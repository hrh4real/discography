# %%
# from dis import dis
# import random as rdm

discography = {
    "outkast" : {
        "Southernplayalisticadillacmuzik": {
            "Player's Ball": {
                "track_number": 1,
                "duration": "4:21",
                "lyrics" : "Man, let me hit that, man ?",
                "credits" : {
                    "vocals" : {
                        "main vocals" : ["Andre '3000' Benjamin", "Antwan Patton"],
                        "background vocals" : [],
                    },
                    "writing" : ["Andre Benjamin", "Antwan Patton", "Patrick Brown", "Raymon Murray",  "Rico Wade"],
                    "production" : ["Organized Noize"]
                }
            },
            "Southernplayalisticadillacmuzik": {
                "track_number": 2,
                "duration": "5:18",
                "lyrics" : "Well its the M-I-crooked letter..",
                "credits" : {
                    "vocals": {
                        "main vocals" : ["Andre '3000' Benjamin", "Antwan Patton"],
                        "background vocals" : [],
                    },
                    "writing" : ["Andre Benjamin", "Antwan Patton"],
                    "production" : ["Organized Noise"],
                }
            },
            "Crumblin' Erb": {
                "track_number": 3,
                "duration": "5:10",
                "lyrics" : "Niggas killing niggas...",
                "credits" : {
                    "vocals" : {
                        "main vocals" : ["Andre '3000' Benjamin", "Antwan Patton"],
                        "background vocals" : [],
                    },
                    "writing" : ["Andre Benjamin", "Antwan Patton", "Patrick Brown"],
                    "production" : ["Organized Noise"]
                }
            }
        },
        "ATLiens": {
            "Two Dope Boyz (In a Cadillac)": {
                "track_number": 1,
                "duration": "2:46",
                "lyrics" : "Its just two dope boys in cadillac ",
                "credits" : {
                    "vocals" : {
                        "main vocals" : ["Andre '3000' Benjamin", "Antwan Patton"],
                        "background vocals" : [],
                    }, # add another nested dictionary for background vocals
                    "writing" : ["Andre Benjamin", "Antwan Patton"],
                    "production" : ["Organized Noise"]
                }
            },
            "ATLiens": {"track_number": 1,
                "duration": "3:50",
                "lyrics" : "It tickles to see you try to be like Mr. Pickles \n Daddy Fat Sax, B-I-G B-O-I",
                "credits" : {
                    "vocals" : {
                        "main vocals" : ["Andre '3000' Benjamin", "Antwan Patton"],
                        "background vocals" : [],
                    },
                    "writing" : ["Andre Benjamin", "Antwan Patton"],
                    "production" : ["Outkast"]
                }
            },
            "Elevators (Me & You)": {
                "track_number": 3,
                "duration": "4:25",
                "lyrics" : "Momma I want to sing, But momma I want to trick and momma sucking dicks now !",
                "credits" : {
                    "vocals" : {
                        "main vocals" : ["Andre '3000' Benjamin", "Antwan Patton"],
                        "background vocals" : [],
                    },
                    "writing" : ["Andre Benjamin", "Antwan Patton"],
                    "production" : ["Organized Noise"]
                }
            }
        },
        # similarly add another albums of Outkast here...
    },
    # add other artists similarly...
}

# function to add a new album

def add_album(discography, artist_name, album_name):
    if artist_name in discography:
        if album_name not in discography[artist_name]:
            discography[artist_name][album_name] = {}
            print(f"Album '{album_name}' added to {artist_name}'s discography")
        else :
            print(f"Album '{album_name}' already exists in {artist_name}'s discpgraphy")


# Add a new song to an album

def add_song(discography, artist_name, album_name, song_name, track_num, duration, lyrics, main_vocals, bg_vocals, writer, producer):
    if artist_name in discography:
        if album_name in discography[artist_name]:
            discography[artist_name][album_name][song_name] = {
                "track_number" : track_num,
                "duration" : duration,
                "lyrics" : lyrics,
                "credits" : {
                    "vocals" : {
                        "main vocals" : main_vocals,
                        "background vocals" : bg_vocals,
                    },
                    "writing" : writer,
                    "production" : producer
                }
            }
            print(f"{song_name} track has been added to the {album_name} album by artist {artist_name}.")
        else :
            print(f"Album {album_name} doesn't exist for artist {artist_name}. Please enter a valid album.")
    else :
        print(f"Artist '{artist_name}' does not exist. Please add the artist first.")



# get song details
def get_song_details(discography, artist_name, album_name, song_name):
    if artist_name in discography:
        if album_name in discography[artist_name]:
            if song_name in discography[artist_name][album_name]:
                return discography[artist_name][album_name][song_name]
            else :
                print(f"{song_name} track is not in the album {album_name}")
                return None
        else :
            print(f"Album '{album_name}' by artist '{artist_name}' does not exist.")
            return None
    else :
        print(f"Artist '{artist_name}' does not exist.")
        return None

# get all songs from an album

def get_album_songs(discography, artist_name, album_name):
    if artist_name in discography:
        if album_name in discography[artist_name]:
            return discography[artist_name][album_name]
        else :
            print(f"Album '{album_name}' by artist '{artist_name}' does not exist.")
            return None
    else :
        print(f"Artist '{artist_name}' does not exist.")
        return None
